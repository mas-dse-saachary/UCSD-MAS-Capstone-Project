# %% [markdown]
# # Feature Exploration

# %% [markdown]
# Notebook to explore and catalog all features created so far in order to evaluate how to best use them

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
listings = pd.read_csv('listings_augmented_2018-05-06_V1.csv',low_memory=False)
listings = listings.drop(columns='Unnamed: 0')

# %%
listings.shape
# Out:
# (5754, 550)

# %%
listings[listings.isnull().any(axis=1)].columns
# Out:
# Index([u'house_rules-Topic0', u'house_rules-Topic1', u'house_rules-Topic2',
#        u'house_rules-Topic3', u'house_rules-Topic4', u'house_rules-Topic5',
#        u'house_rules-Topic6', u'house_rules-Topic7', u'house_rules-Topic8',
#        u'house_rules-Topic9',
#        ...
#        u'has"First Aid Kit"', u'hasDog(s)', u'has"Wireless Internet"',
#        u'has"Cable TV"', u'hasPool', u'hasBreakfast', u'hasDoorman',
#        u'has"Lock on Bedroom Door"', u'has"24-Hour Check-in"',
#        u'distance from ocean'],
#       dtype='object', length=550)

# %%
pd.isnull(listings).any(axis=1)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#         ...
# 5724    True
# 5725    True
# 5726    True
# 5727    True
# 5728    True
# 5729    True
# 5730    True
# 5731    True
# 5732    True
# 5733    True
# 5734    True
# 5735    True
# 5736    True
# 5737    True
# 5738    True
# 5739    True
# 5740    True
# 5741    True
# 5742    True
# 5743    True
# 5744    True
# 5745    True
# 5746    True
# 5747    True
# 5748    True
# 5749    True
# 5750    True
# 5751    True
# 5752    True
# 5753    True
# Length: 5754, dtype: bool

# %%
listings.isnull().sum()
# Out:
# house_rules-Topic0                                 0
# house_rules-Topic1                                 1
# house_rules-Topic2                                 1
# house_rules-Topic3                                 0
# house_rules-Topic4                                 0
# house_rules-Topic5                                 0
# house_rules-Topic6                                 1
# house_rules-Topic7                                 0
# house_rules-Topic8                                 0
# house_rules-Topic9                                 0
# house_rules-Topic10                                0
# house_rules-Topic11                                0
# house_rules-Topic12                                0
# house_rules-Topic13                                1
# house_rules-Topic14                                0
# house_rules-Topic15                                1
# house_rules-Topic16                                0
# house_rules-Topic17                                0
# ...

# %%
plt.figure(figsize=(40, 20))
plt.scatter(x=[i for i in range(len(listings[listings.isnull().any(axis=1)].columns))],y=listings[listings[listings.isnull().any(axis=1)].columns].isnull().sum())
#plt.xlabel([i for i in range(len(listings[listings.isnull().any(axis=1)].columns))])
plt.show()
